# %%
from IPython.display import Image

# %% [markdown]
# ## zero redundancy optimizer

# %% [markdown]
# - ZeRO
#     - DDP + ZeRO
#     - `opt.step()`
#         - sharded parameters
#         - local states
# - memory footprint

# %%
Image('../imgs/zero-red.png', width=600)
